# %%
import selenium
import pandas as pd 
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time 

import warnings
warnings.filterwarnings('ignore')

# %%
# Answer No. 1

# To connect to the driver
driver = webdriver.Chrome(r"C:\Users\rehan\Downloads\chromedriver_win32\chromedriver.exe")

# %%
# To open the naukari page in the automated chrome browser
driver.get('https://www.naukri.com/')

# %%
# To enter the designation name 
designation = driver.find_element(By.CLASS_NAME, 'suggestor-input')
designation.send_keys('Data Analyst')

# %%
# To enter the location 
location = driver.find_element(By.XPATH,"/html/body/div[1]/div[7]/div/div/div[5]/div/div/div/div[1]/div/input")
location.send_keys('Bangalore')

# %%
# To click on the search button to get the search results
search = driver.find_element(By.CLASS_NAME, 'qsbSubmit')
search.click()

# %%
# To store the data
job_title = []
job_location = []
company_name = []

# %%
# Scraping job title from the naukari page
title_tag = driver.find_elements(By.XPATH, '//a[@class="title ellipsis"]')
for i in title_tag[0:10]:
    title = i.text
    job_title.append(title)
    
# Scraping job location form the naukari page
location_tag = driver.find_elements(By.XPATH, '//span[@class="ellipsis fleft locWdth"]')
for i in location_tag[0:10]:
    location = i.text
    job_location.append(location)
    
# Scraping company name from the naukari page
company_tag = driver.find_elements(By.XPATH, '//a[@class="subTitle ellipsis fleft"]')
for i in company_tag[0:10]:
    company = i.text
    company_name.append(company)

# %%
print(len(job_title),len(job_location),len(company_name))
# Out:
# 10 10 10

# %%
df = pd.DataFrame({'Title' : job_title, 'Location': job_location, 'Company': company_name})
df
# Out:
#                                        Title  \
# 0                               Data Analyst
# 1                               Data Analyst
# 2                               Data Analyst
# 3  Environmental Sustainability Data Analyst
# 4                               Data Analyst
# 5                               Data Analyst
# 6                      Data Analyst - EdTech
# 7                               Data Analyst
# 8                 Data Engineer/Data Analyst
# 9                 Data Analyst - Contractual
#
#                                             Location  \
# 0                                Bangalore/Bengaluru
# 1                                Bangalore/Bengaluru
# 2                                Bangalore/Bengaluru
# 3  Bangalore/Bengaluru, Kolkata, Mumbai, New Delh...
# 4                                Bangalore/Bengaluru
# 5                                Bangalore/Bengaluru
# 6                                Bangalore/Bengaluru
# 7                                Bangalore/Bengaluru
# 8  Hybrid - Bangalore/Bengaluru, Kolkata, Hyderab...
# 9                                Bangalore/Bengaluru
#
#                         Company
# 0                  Globals Ites
# 1                        Varite
# 2  Cynosure Corporate Solutions
# 3             PerkinElmer, Inc.
# 4                NNE Pharmaplan
# 5                Ingersoll Rand
# 6                   Talentstack
# 7                  Unusual Hire
# 8                 Tech Mahindra
# 9  Search Advisers Services Guj

# %%
# Answer No.2

driver = webdriver.Chrome(r'C:\Users\rehan\Downloads\chromedriver_win32\chromedriver.exe')

driver.get('https://www.naukri.com/')

# %%
designation = driver.find_element(By.CLASS_NAME, 'suggestor-input')
designation.send_keys('Data Scientist')

location = driver.find_element(By.XPATH,"/html/body/div[1]/div[7]/div/div/div[5]/div/div/div/div[1]/div/input")
location.send_keys('Bangalore')


search = driver.find_element(By.CLASS_NAME, 'qsbSubmit')
search.click()

# %%
job_title = []
job_location = []
company_name = []

# %%
# Scraping job title from the naukari page
title_tag = driver.find_elements(By.XPATH, '//a[@class="title ellipsis"]')
for i in title_tag[0:10]:
    title = i.text
    job_title.append(title)
    
# Scraping job location form the naukari page
location_tag = driver.find_elements(By.XPATH, '//span[@class="ellipsis fleft locWdth"]')
for i in location_tag[0:10]:
    location = i.text
    job_location.append(location)
    
# Scraping company name from the naukari page
company_tag = driver.find_elements(By.XPATH, '//a[@class="subTitle ellipsis fleft"]')
for i in company_tag[0:10]:
    company = i.text
    company_name.append(company)

# %%
print(len(job_title),len(job_location),len(company_name))
# Out:
# 10 10 10

# %%
df = pd.DataFrame({'Title' : job_title, 'Location': job_location, 'Company': company_name})
df
# Out:
#                                                Title  \
# 0  Data Science Professional - IBM SPSS Statistic...
# 1                            Data Science Specialist
# 2                   Analystics & Modeling Specialist
# 3                              Senior data scientist
# 4                                 Data Scientist_NLP
# 5                                     Data Scientist
# 6                    Machine Learning (AI) Architect
# 7                                 Sr. Data scientist
# 8       Manager - Innovations Hub - Machine Learning
# 9                                Lead Data Scientist
#
#                                             Location                Company
# 0  Bangalore/Bengaluru, Noida, Mumbai, Pune, Chennai  Hexaware Technologies
# 1  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...              Accenture
# 2  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...              Accenture
# 3  Bangalore/Bengaluru, Mumbai, Pune, Chennai, Gu...      Fractal Analytics
# 4  Bangalore/Bengaluru, Mumbai, Pune, Chennai, Gu...      Fractal Analytics
# 5  Bangalore/Bengaluru, Mumbai, Pune, Chennai, Gu...      Fractal Analytics
# 6  Bangalore/Bengaluru, Kolkata, Mumbai, New Delh...             Persistent
# 7   Hybrid - Bangalore/Bengaluru, Mumbai (All Areas)                   PayU
# 8  Bangalore/Bengaluru, Mumbai, Hyderabad/Secunde...                    PwC
# 9                                Bangalore/Bengaluru                Genpact

# %%
# Answer No.3

driver = webdriver.Chrome(r'C:\Users\rehan\Downloads\chromedriver_win32\chromedriver.exe')

driver.get('https://www.naukri.com/')

# %%
designation = driver.find_element(By.CLASS_NAME, 'suggestor-input')
designation.send_keys('Data Scientist')

search = driver.find_element(By.CLASS_NAME, 'qsbSubmit')
search.click()

# %%
loc_filter = driver.find_element(By.XPATH, "/html/body/div[1]/div[4]/div/div/section[1]/div[2]/div[5]/div[2]/div[2]/label/i")
loc_filter.click()

# %%
salary_filter = driver.find_element(By.XPATH, "/html/body/div[1]/div[4]/div/div/section[1]/div[2]/div[6]/div[2]/div[2]/label/i")
salary_filter.click()

# %%
job_title = []
job_location = []
company_name = []
experience = []

# %%
# Scraping job title from the naukari page
title_tag = driver.find_elements(By.XPATH, '//a[@class="title ellipsis"]')
for i in title_tag[0:10]:
    title = i.text
    job_title.append(title)
    
# Scraping job location form the naukari page
location_tag = driver.find_elements(By.XPATH, '//span[@class="ellipsis fleft locWdth"]')
for i in location_tag[0:10]:
    location = i.text
    job_location.append(location)
    
# Scraping company name from the naukari page
company_tag = driver.find_elements(By.XPATH, '//a[@class="subTitle ellipsis fleft"]')
for i in company_tag[0:10]:
    company = i.text
    company_name.append(company)
    
    
exp_tag = driver.find_elements(By.XPATH, '//span[@class="ellipsis fleft expwdth"]')
for i in exp_tag[0:10]:
    expr = i.text
    experience.append(expr)

# %%
print(len(job_title),len(job_location),len(company_name), len(experience))
# Out:
# 10 10 10 10

# %%
df = pd.DataFrame({'Title' : job_title, 'Location': job_location, 'Company': company_name, 'Experience': experience})
df
# Out:
#                                                Title  \
# 0                                     Data Scientist
# 1                              Junior Data Scientist
# 2                                     Data Scientist
# 3                                     Data Scientist
# 4                                     Data Scientist
# 5                              Junior Data Scientist
# 6                               Analyst-Data Science
# 7                               Analyst-Data Science
# 8  Assistant Manager/Senior Manager - Data Scientist
# 9         Data Scientist - Python + Machine Learning
#
#                                             Location  \
# 0  Temp. WFH - Kochi/Cochin, Kolkata, Hyderabad/S...
# 1  Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...
# 2              Gurgaon/Gurugram, Bangalore/Bengaluru
# 3  Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...
# 4  Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...
# 5    Gurgaon/Gurugram, United States (USA), Bulgaria
# 6                                   Gurgaon/Gurugram
# 7                                   Gurgaon/Gurugram
# 8              Gurgaon/Gurugram, Bangalore/Bengaluru
# 9                   Hybrid - Noida, Gurgaon/Gurugram
#
#                            Company Experience
# 0                        Cognizant   6-10 Yrs
# 1                         Analytos    0-2 Yrs
# 2                        Blackbuck    3-7 Yrs
# 3                        Tabsquare    1-3 Yrs
# 4                         Analytos    2-4 Yrs
# 5                           Adidas    1-6 Yrs
# 6                 AMERICAN EXPRESS    0-3 Yrs
# 7                 AMERICAN EXPRESS    0-3 Yrs
# 8        Huquo Consulting Pvt. Ltd    2-7 Yrs
# 9  ERM Placement Services (p) Ltd.    3-7 Yrs

# %%
# Answer No. 4

driver = webdriver.Chrome(r'C:\Users\rehan\Downloads\chromedriver_win32\chromedriver.exe')

driver.get('https://flipkart.com/')

# %%
product = driver.find_element(By.XPATH, '/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input')
product.send_keys('Sunglasses')

# %%
submit = driver.find_element(By.CLASS_NAME,"L0Z3Pu")
submit.click()

# %%
brand_name = []
prod_disc = []
price = []
Rating =[]

# %%
start=0
end=3
for page in range(start, end):
    brand = driver.find_elements(By.XPATH, '//div[@class="_2WkVRV"]')
    for i in brand[0:99]:
        brnd = i.text
        brand_name.append(brnd)
        
#     try:
#         product_disc = driver.find_elements(By.XPATH, '//a[@class="IRpwTa"]')
#         for i in product_disc[0:99]:
#             pd = i.text
#             prod_disc.append(pd)
        
#             if len(prod_disc) < 99:
#                 raise ValueError("Insufficient data retrieved")
#     except ValueError as e:
#         print(f"Error: {e}")
#     # If there is insufficient data, filter the existing data
#         prod_disc = [i for i in product_disc if i.text != "99"]

# Product discription is not fetching the sufficient data
        
    mrp = driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for i in mrp[0:99]:
        rupee = i.text
        price.append(rupee)
        
    rate = driver.find_elements(By.XPATH,'//div[@class="_3Ay6Sb"]')
    for i in rate[0:99]:
        rt = i.text
        Rating.append(rt)
    next_page = driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_page.click()
    time.sleep(4)

# %%
df = pd.DataFrame({'Brand' : brand_name, 'Price': price})
df
# Out:
#               Brand   Price
# 0     VINCENT CHASE  ₹1,061
# 1      Singco India    ₹449
# 2          Fastrack    ₹489
# 3            PIRASO    ₹211
# 4          Fastrack    ₹589
# ..              ...     ...
# 115  ROZZETTA CRAFT    ₹516
# 116  kingsunglasses    ₹193
# 117        Fastrack    ₹544
# 118  kingsunglasses    ₹190
# 119  ROZZETTA CRAFT    ₹516
#
# [120 rows x 2 columns]

# %%
# Answer no.5

driver = webdriver.Chrome(r'C:\Users\rehan\Downloads\chromedriver_win32\chromedriver.exe')

driver.get('https://www.flipkart.com/apple-iphone-11-black-64-gb/product-reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&marketplace=FLIPKART')

# %%
# Initialize empty lists

Rating =[]
Summary = []
Full_review = []

# %%
start = 0
end = 10
for page in range(start, end+1):
    rating_ = driver.find_elements(By.XPATH, '//div[@class="_3LWZlK _1BLPMq"]')
    for i in rating_:
        rate = i.text
        Rating.append(rate)

    summary_ = driver.find_elements(By.XPATH, '//p[@class="_2-N8zT"]')
    for i in summary_:
        summ = i.text
        Summary.append(summ)

    review_ = driver.find_elements(By.XPATH, '//div[@class="t-ZTKy"]')
    for i in review_:
        rview = i.text
        Full_review.append(rview)

    try:
        next_page = driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
        next_page.click()
        time.sleep(3)
    except:
        print("Reached last page")
        break

# %%
df = pd.DataFrame({'Rating' : Rating, 'Summary': Summary, 'Full Review': Full_review})
df
# Out:
#     Rating              Summary  \
# 0        5       Simply awesome
# 1        5     Perfect product!
# 2        5  Best in the market!
# 3        4      Value-for-money
# 4        5   Highly recommended
# ..     ...                  ...
# 105      5     Perfect product!
# 106      5   Highly recommended
# 107      4      Value-for-money
# 108      5   Highly recommended
# 109      5     Perfect product!
#
#                                            Full Review
# 0    Really satisfied with the Product I received.....
# 1    Amazing phone with great cameras and better ba...
# 2    Great iPhone very snappy experience as apple k...
# 3    I'm Really happy with the product\nDelivery wa...
# 4    It's my first time to use iOS phone and I am l...
# ..                                                 ...
# 105  Value for money❤️❤️\nIts awesome mobile phone ...
# 106  iphone 11 is a very good phone to buy only if ...
# 107  Just got this iphone 11\nAnd it is most powerf...
# 108  Amazing camera quality as expected, battery al...
# 109  It is just awesome mobile for this price from ...
#
# [110 rows x 3 columns]

# %%
# Answer no.6

driver = webdriver.Chrome(r'C:\Users\rehan\Downloads\chromedriver_win32\chromedriver.exe')

driver.get('https://flipkart.com/')

sneaker = driver.find_element(By.XPATH, '/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input')
sneaker.send_keys('Sneakers')

# %%
submit = driver.find_element(By.CLASS_NAME,"L0Z3Pu")
submit.click()

# %%
Brand = []
Discription = []
Price = []

# %%
start = 0
end = 2
for page in range(start, end+1):
    brand_ = driver.find_elements(By.XPATH, '//div[@class="_2WkVRV"]')
    for i in brand_:
        bnd = i.text
        Brand.append(bnd)

    disc_ = driver.find_elements(By.XPATH, '//a[@class="IRpwTa"]')
    for i in disc_:
        discr = i.text
        Discription.append(discr)

    price_ = driver.find_elements(By.XPATH, '//div[@class="_30jeq3"]')
    for i in price_:
        pric = i.text
        Price.append(pric)

    try:
        next_page = driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
        next_page.click()
        time.sleep(3)
    except:
        print("Reached last page")
        break

# %%
print(len(Brand),len(Discription), len(Price))
# Out:
# 120 119 120

# %%
df = pd.DataFrame({'Brand' : Brand, 'Price': Price})
df
# Out:
#              Brand   Price
# 0           Labbin    ₹494
# 1           Labbin    ₹694
# 2              SFR    ₹299
# 3           Kraasa    ₹299
# 4            BIRDE    ₹499
# ..             ...     ...
# 115          BIRDE    ₹299
# 116    New Balance  ₹3,540
# 117       RapidBox    ₹571
# 118  WHITE WALKERS    ₹449
# 119          BIRDE    ₹499
#
# [120 rows x 2 columns]

# %%
# Answer no.7

driver = webdriver.Chrome(r'C:\Users\rehan\Downloads\chromedriver_win32\chromedriver.exe')

driver.get('https://www.amazon.in/')

# %%
laptop = driver.find_element(By.XPATH, "/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input")
laptop.send_keys('Laptop')

submit = driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input')
submit.click()

Filter = driver.find_element(By.XPATH,"/html/body/div[1]/div[2]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[6]/ul[7]/li[13]/span/a/div/label/i")
Filter.click()

# %%
Title = []
Rating = []
Price = []

# %%
title_tag = driver.find_elements(By.XPATH, '//span[@class="a-size-medium a-color-base a-text-normal"]')
for i in title_tag[0:10]:
    title_ = i.text
    Title.append(title_)
    
rating_tag = driver.find_elements(By.XPATH, '//i[@class="a-icon a-icon-star-small a-star-small-4 aok-align-bottom"]')
for i in rating_tag[0:20]:
    rate = i.text
    Rating.append(rate)
    
price_tag = driver.find_elements(By.XPATH, '//span[@class="a-price-whole"]')
for i in price_tag[0:10]:
    mrp = i.text
    Price.append(mrp)

# %%
df = pd.DataFrame({'Title' : Title, 'Price': Price})
df
# Out:
#                                                Title   Price
# 0  ASUS VivoBook 14 (2021), 14-inch (35.56 cm) HD...  27,990
# 1  ASUS Eeebook 14, 14-inch (35.56 cms) HD, Intel...  25,990
# 2  Dell Vostro 3510 Laptop, Intel Pentium Gold 75...  32,990
# 3  Acer Travelmate Business Laptop Intel Pentium ...  28,990
# 4  ASUS Intel Pentium Quad Core 15.6 inches Busin...  23,190
# 5  Acer Extensa 15 Thin & Light Intel Processor P...  28,990
# 6  Acer Extensa Pentium Silver N5030 - (Intel, 8 ...  29,990
# 7  Acer Travelmate Intel® Pentium® Gold 7505 Proc...  56,990
# 8  Microsoft Surface GO 3 Black Intel Pentium T66...  23,992
# 9  (Renewed) Acer Travelmate Intel® Pentium® Gold...  12,999

# %%
# Answer no.8

driver = webdriver.Chrome(r'C:\Users\rehan\Downloads\chromedriver_win32\chromedriver.exe')

driver.get('https://www.azquotes.com/top_quotes.html')

# %%
search = driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/div[1]/div/div[2]/div[1]/div/form/input[3]")
search.click()

# %%
Quote = []
Author = []
Genre = []

# %%
start = 0
end = 10
for page in range(start, end+1):
    quote_ = driver.find_elements(By.XPATH, '//a[@class="title"]')
    for i in quote_:
        qt = i.text
        Quote.append(qt)

    author_ = driver.find_elements(By.XPATH, '//div[@class="author"]')
    for i in author_:
        au = i.text
        Author.append(au)

    genre_ = driver.find_elements(By.XPATH, '//div[@class="tags"]')
    for i in genre_:
        gnr = i.text
        Genre.append(gnr)

    try:
        next_page = driver.find_element(By.XPATH,'//li[@class="next"]')
        next_page.click()
        time.sleep(3)
    except:
        print("Reached last page")
        break
# Out:
# Reached last page

# %%
df = pd.DataFrame({'Quote' : Quote, 'Author': Author, 'Genre': Genre})
df
# Out:
#                                                  Quote              Author  \
# 0    The essence of strategy is choosing what not t...      Michael Porter
# 1    One cannot and must not try to erase the past ...          Golda Meir
# 2    Patriotism means to stand by the country. It d...  Theodore Roosevelt
# 3    Death is something inevitable. When a man has ...      Nelson Mandela
# 4    You have to love a nation that celebrates its ...        Erma Bombeck
# ..                                                 ...                 ...
# 995  Regret for the things we did can be tempered b...    Sydney J. Harris
# 996  America... just a nation of two hundred millio...  Hunter S. Thompson
# 997  For every disciplined effort there is a multip...            Jim Rohn
# 998  The spiritual journey is individual, highly pe...            Ram Dass
# 999  The mind is not a vessel to be filled but a fi...            Plutarch
#
#                                         Genre
# 0    Essence, Deep Thought, Transcendentalism
# 1                   Inspiration, Past, Trying
# 2                         Country, Peace, War
# 3          Inspirational, Motivational, Death
# 4                4th Of July, Food, Patriotic
# ..                                        ...
# 995         Love, Inspirational, Motivational
# 996                    Gun, Two, Qualms About
# 997     Inspirational, Greatness, Best Effort
# 998                    Spiritual, Truth, Yoga
# 999      Inspirational, Leadership, Education
#
# [1000 rows x 3 columns]

# %%
# Answer no.10

driver = webdriver.Chrome(r'C:\Users\rehan\Downloads\chromedriver_win32\chromedriver.exe')

driver.get('https://www.motor1.com/features/308149/most-expensive-new-cars-ever/')

# %%
car_name = []
price = []

# %%
auto = driver.find_elements(By.TAG_NAME, 'h3')
for i in auto:
    car1 = i.text
    car_name.append(car1)

price_ = driver.find_elements(By.TAG_NAME, 'strong')
for i in price_:
    pr = i.text
    price.append(pr)

# %%
car_name
# Out:
# ['De Tomaso P72',
#  'Ferrari LaFerrari',
#  'Pagani Huayra',
#  'McLaren Elva',
#  'Czinger 21C',
#  'Ferrari Monza',
#  'Gordon Murray T.33',
#  'Koenigsegg Gemera',
#  'Zenvo TSR-S',
#  'Hennessey Venom F5',
#  'Bentley Bacalar',
#  'Hispano Suiza Carmen Boulogne',
#  'Bentley Mulliner Batur',
#  'Deus Vayanne',
#  'SSC Tuatara',
#  'Lotus Evija',
#  'Aston Martin Vulcan',
#  'Delage D12',
#  'McLaren Speedtail',
#  'Rimac Nevera',
#  'Pagani Utopia',
#  'Pininfarina Battista',
#  'Ferrari FXX K Evo',
#  'Gordon Murray T.50',
#  'Lamborghini Countach',
#  'Mercedes-AMG Project One',
#  'Aston Martin Victor',
#  'Hennessey Venom F5 Roadster',
#  'Koenigsegg Jesko',
#  'Aston Martin Valkyrie',
#  'W Motors Lykan Hypersport',
#  'McLaren Solus',
#  'Pagani Huayra Roadster BC',
#  'Bugatti Chiron Pur Sport',
#  'Lamborghini Sian',
#  'Koenigsegg CC850',
#  'Bugatti Chiron Super Sport 300+',
#  'Lamborghini Veneno',
#  'Bugatti Bolide',
#  'Bugatti Mistral',
#  'Pagani Huayra Imola',
#  'Bugatti Divo',
#  'SP Automotive Chaos',
#  'Pagani Codalunga',
#  'Mercedes-Maybach Exelero',
#  'Bugatti Centodieci',
#  'Bugatti Chiron Profilée',
#  'Rolls-Royce Sweptail',
#  'Bugatti La Voiture Noire',
#  'Rolls-Royce Boat Tail*',
#  'FAQs',
#  'Most Expensive Cars In The World']

# %%
df = pd.DataFrame({'Car Name': car_name, 'Price': price})
print(df)
